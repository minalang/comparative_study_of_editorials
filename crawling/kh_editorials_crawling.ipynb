# %%
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import csv
import time
import pandas as pd

# %%
import pandas as pd
import numpy as np

from selenium import webdriver
from selenium.webdriver import ActionChains as AC
from tqdm.notebook import tqdm
import re # 정규표현식 - 해시태그 제거
import time

# %%
url_load=pd.read_csv("kh_url.CSV", encoding='cp949')
url_load
# Out:
#                                                   URL
# 0   https://www.khan.co.kr/opinion/editorial/artic...
# 1   https://www.khan.co.kr/opinion/editorial/artic...
# 2   https://www.khan.co.kr/opinion/editorial/artic...
# 3   https://www.khan.co.kr/opinion/editorial/artic...
# 4   https://www.khan.co.kr/opinion/editorial/artic...
# 5   http://news.khan.co.kr/kh_news/khan_art_view.h...
# 6   http://news.khan.co.kr/kh_news/khan_art_view.h...
# 7   http://news.khan.co.kr/kh_news/khan_art_view.h...
# 8   http://news.khan.co.kr/kh_news/khan_art_view.h...
# 9   http://news.khan.co.kr/kh_news/khan_art_view.h...
# 10  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 11  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 12  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 13  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 14  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 15  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 16  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 17  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 18  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 19  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 20  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 21  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 22  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 23  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 24  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 25  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 26  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 27  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 28  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 29  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 30  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 31  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 32  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 33  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 34  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 35  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 36  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 37  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 38  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 39  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 40  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 41  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 42  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 43  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 44  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 45  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 46  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 47  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 48  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 49  http://news.khan.co.kr/kh_news/khan_art_view.h...

# %%
url_load=pd.read_csv("kh_url.CSV", encoding='cp949')


num_list = len(url_load)

print(num_list)
url_load

dict = {}    # 전체 크롤링 데이터를 담을 그릇

number = 50  # 수집할 사설의 개수 정하기

path = "./chromedriver.exe"

# 수집한 url 돌면서 데이터 수집
for i in tqdm(range(0, number)):
    # 글 띄우기
    url = url_load['URL'][i]
    driver = webdriver.Chrome(path)  # 윈도우는 "chromedriver.exe"
    driver.get(url)   # 글 띄우기
    
    # 크롤링
    
    try:
     
        # iframe 접근
        #driver.switch_to.frame('mainFrame')

        target_info = {}  # 개별 사설 내용을 담을 딕셔너리 생성

        # 제목 크롤링 시작
        overlays = "h1.headline"                                 
        tit = driver.find_element_by_css_selector(overlays)          # title
        title = tit.text
    
        # 내용 크롤링
        overlays = "div.art_body"                                 
        contents = driver.find_elements_by_css_selector(overlays)    # contents
        #print(contents)

        content_list = []
        for content in contents:
            content_list.append(content.text)
 
        content_str = ' '.join(content_list)                         # content_str

        # 글 하나는 target_info라는 딕셔너리에 담기게 되고,
        target_info['title'] = title
        target_info['content'] = content_str

        # 각각의 글은 dict라는 딕셔너리에 담기게 됩니다.
        dict[i] = target_info
        time.sleep(1)
        
        # 크롤링이 성공하면 글 제목을 출력하게 되고,
        print(i, title)

        # 글 하나 크롤링 후 크롬 창을 닫습니다.
        driver.close()
        
    except Exception as e:
        print(e,'This page is error :',i)
        driver.close()
        time.sleep(1)
        continue
        
    # 에러나면 현재 크롬창을 닫고 다음 글(i+1)로 이동합니다.
    
    # 중간,중간에 파일로 저장하기
    if i == 30 or 50 or 80:
        # 판다스로 만들기
        import pandas as pd
        result_df = pd.DataFrame.from_dict(dict, 'index')

        # 저장하기
        result_df.to_excel("경향신문.xlsx", encoding='utf-8-sig')
        time.sleep(3)

print('수집한 글 갯수: ', len(dict))

# 판다스로 만들기
import pandas as pd
result_df = pd.DataFrame.from_dict(dict, 'index')
result_df
# Out:
# 50
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=50.0), HTML(value='')))
# 0 대선 앞 돌출한 재난지원금, 예산국회서 신중히 따져보길
# 1 넉 달째 2% 상승세 소비자물가, 당국은 엄중하게 대처해야
# 2 당정, 코로나로 민생 무너지는데 또 재난지원금 논란인가
# 3 수도권 12일부터 4단계, 자영업 지원 신속하고 담대하게
# 4 청년·부동산·추경 강조한 송영길, 문제해결 능력 보여야
# 5 20조 재난지원에 손실보상까지 ‘경제백신’도 속도내야
# 6 심화된 코로나 가계소득 양극화, 정부 더 과감해야 할 이유
# 7 4차 재난지원금, 피해계층에 두껍게 지원하는 게 옳다
# 8 4차 재난지원금 놓고 또 당정 갈등, 조기에 매듭지어야
# 9 시대착오적인 국민의힘의 ‘국회 대정부질문 지침’
# 10 소급 적용 않는다는 여당, 지난 손실 어떻게 보상할 건가
# 11 자영업자 손실보상제, 재정 확장한 첫 모델 만들어라
# 12 자영업자 손실 보상, 파격적인 수준으로 이뤄져야
# 13 회복·도약·포용 다짐한 문 대통령, 민생서 구체적 성과 내야
# 14 4차 재난지원금 앞서 피해 및 소득 파악 시스템 구축부터
# 15 4차도 전 국민 재난지원금도 지금부터 준비해나갈 때다
# 16 형평성 시비 커지는 ‘코로나 영업제한’, 보완책 서둘러야
# 17 사상 처음 GDP 넘은 가계 빚, 정부는 각별히 관리해야
# 18 새해 경제정책, 취약계층 보호·지원에 무게 더 실어야
# 19 소상공인·자영업자 임대료 고통분담 더 미룰 수 없다
# 20 6년 만에 법정시한 내 예산안 처리에 합의한 여야
# 21 3차 재난지원금 논의, 지금부터 준비해 나가야
# 22 취약층·2030 직격한 ‘코로나 실업 양극화’ 경각심 높일 때다
# 23 여야 합의 통과된 4차 추경, 재난지원금 차질 없이 지급해야
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1.headline"}
#   (Session info: chrome=95.0.4638.69)
#  This page is error : 24
# 25 심상정의 ‘피해단계별 임대료 감면’ 논의할 만하다
# 26 재난지원금 혼선, 국회서 책임 있게 매듭짓고 추경 서둘러라
# 27 ‘형평성 논란’ 2차 재난지원금 보완 대책 서둘러야
# 28 ‘코로나 폐업’ 벼랑 몰린 자영업, ‘착한 임대’로 숨통 터줘야
# 29 2차 재난지원금 ‘선별지급’ 결정, 국민에 충분히 설명해야
# 30 2차 재난지원금, 실효성·공정성 위해 정밀히 설계해야
# 31 ‘상원 법사위’ 개혁하고 정기국회는 ‘코로나 민생’ 집중하라
# 32 이낙연 체제, 코로나·민생·협치 답 찾는 여당 돼야
# 33 공감 커지는 2차 재난지원금 지급, 정부는 준비해야
# 34 정치권, 코로나 공방 멈추고 2차 재난지원금 논의하라
# 35 취약계층·소상공인 ‘코로나 시름’ 보듬는 대책 서둘러야
# 36 67년째 ‘노동자’인 적 없는 법 밖의 가사노동자들
# 46  이인영 더불어민주당 원내대표가 17일 “총선이 끝난 만큼 야당과 추가경정예산안 심사...
# 47  금호석유화학그룹이 코로나19 극복을 위해 임원을 제외한 그룹 전 계열사 직원 220...
# 48  예금과 적금, 보험을 중도에 해지하는 서민들이 늘고 있다. 코로나19로 경제활동이 ...
# 49  더불어민주당 이해찬 대표가 6일 코로나19 긴급재난지원금에 대해 “지역·소득과 관계...

# %%
result_df.to_csv("경향신문.csv", encoding='utf-8')

# %%
print(result_df)
# Out:
#                                   title  \
# 0        대선 앞 돌출한 재난지원금, 예산국회서 신중히 따져보길
# 1      넉 달째 2% 상승세 소비자물가, 당국은 엄중하게 대처해야
# 2        당정, 코로나로 민생 무너지는데 또 재난지원금 논란인가
# 3       수도권 12일부터 4단계, 자영업 지원 신속하고 담대하게
# 4        청년·부동산·추경 강조한 송영길, 문제해결 능력 보여야
# 5         20조 재난지원에 손실보상까지 ‘경제백신’도 속도내야
# 6      심화된 코로나 가계소득 양극화, 정부 더 과감해야 할 이유
# 7         4차 재난지원금, 피해계층에 두껍게 지원하는 게 옳다
# 8        4차 재난지원금 놓고 또 당정 갈등, 조기에 매듭지어야
# 9            시대착오적인 국민의힘의 ‘국회 대정부질문 지침’
# 10      소급 적용 않는다는 여당, 지난 손실 어떻게 보상할 건가
# 11         자영업자 손실보상제, 재정 확장한 첫 모델 만들어라
# 12           자영업자 손실 보상, 파격적인 수준으로 이뤄져야
# 13    회복·도약·포용 다짐한 문 대통령, 민생서 구체적 성과 내야
# 14      4차 재난지원금 앞서 피해 및 소득 파악 시스템 구축부터
# 15        4차도 전 국민 재난지원금도 지금부터 준비해나갈 때다
# 16      형평성 시비 커지는 ‘코로나 영업제한’, 보완책 서둘러야
# 17      사상 처음 GDP 넘은 가계 빚, 정부는 각별히 관리해야
# 18        새해 경제정책, 취약계층 보호·지원에 무게 더 실어야
# 19         소상공인·자영업자 임대료 고통분담 더 미룰 수 없다
# 20          6년 만에 법정시한 내 예산안 처리에 합의한 여야
# 21            3차 재난지원금 논의, 지금부터 준비해 나가야
# 22  취약층·2030 직격한 ‘코로나 실업 양극화’ 경각심 높일 때다
# 23    여야 합의 통과된 4차 추경, 재난지원금 차질 없이 지급해야
# 25          심상정의 ‘피해단계별 임대료 감면’ 논의할 만하다
# 26     재난지원금 혼선, 국회서 책임 있게 매듭짓고 추경 서둘러라
# 27         ‘형평성 논란’ 2차 재난지원금 보완 대책 서둘러야
# 28  ‘코로나 폐업’ 벼랑 몰린 자영업, ‘착한 임대’로 숨통 터줘야
# 29     2차 재난지원금 ‘선별지급’ 결정, 국민에 충분히 설명해야
# 30        2차 재난지원금, 실효성·공정성 위해 정밀히 설계해야
# 31    ‘상원 법사위’ 개혁하고 정기국회는 ‘코로나 민생’ 집중하라
# 32         이낙연 체제, 코로나·민생·협치 답 찾는 여당 돼야
# 33         공감 커지는 2차 재난지원금 지급, 정부는 준비해야
# 34        정치권, 코로나 공방 멈추고 2차 재난지원금 논의하라
# 35       취약계층·소상공인 ‘코로나 시름’ 보듬는 대책 서둘러야
